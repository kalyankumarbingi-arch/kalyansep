# %%
==================== Data Analysis =============================
1. Pandas         :  Data frame analysis
2. Numpy          :  Numerical analysis
3. matplotlib     :  Graphs and plots
4. seaborn        :  plots
5. Bokhe         :   plots
6. plotly         :  plots

=================== Machine Learning ============================
7. stats          : for statistical models
8. scikit-learn(sklearn) :  ML models

===================  Deep learning ============================
9. opencv         : Computer vision
10. pillow        : Image operations
11. tensorflow    : Neural Network creations (developed by google)
12. keras         : NN
13. pytorch       : alternative package of tensorflow (facebook meta)

==================== NLP ========================================
14. NLTK          : Natural language toolkit
15. SpaCy         : Alternative to NLTK
16. wordcloud     : most frequent occured words       

======================= Scarapping =================================
17. SqLite        : Data base creation
18. Beautiful soup
19. Selenium

======================== API creations ===========================
20. Flask
21. FastAPI
22. Gradio
23. Django
======================= UI app creation =========================
24.Streamlit

===================== Transfer learning models(DL) ===========
25. Mobilenet
26. Resnet
27. VGGnet
28. Inception
29. Yolo    :  Ultralytics

===================== Transfer learning models(NLP) ===========
30. Word2vec
31. GloVe

======================== Hugging Face Transformers ===============
32. BERT   : Bi Directional Encoder representation of Transformers

========================== Allen NLP =======================
33. Allen NLP packages

================== GenAI =============================
34. LangChain
35. Google GeminiAi realted pcakges
36. OpenAI GPT realted packages
37. Amazon BedRock realted packages
38. Meta Llama  related packages
39. Anthropic

==================== Image and Video Generations ==============
39. GAN models realted packages
40. SORA related packages
41. nano banana

=================== Model deployment (MlOps)===================
41. mlflow using databricks
42. kubeflow (GCP account)

==================== Cloud applications =====================
43. Azure ML realted packages
44. GCP VertexAI related packages
45. AWS Sagemaker realted packages

==================== small ===================================
46. time
47. logging
48. math
49. random
50. env
51. os

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Names=['Ramesh','Suresh','Sathish','Mahesh']
Age=[20,22,24,26]

# %% [markdown]
# **Step-1:Create a Dataframe**

# %%
#pd.DataFrame(data,index,columns,dtype,copy)
pd.DataFrame(Names)
#pd.DataFrame(Names,'Names') # Names assume as index
#pd.DataFrame(Names,columns='Names') # Columns array 
pd.DataFrame(Names,columns=['Names'])
# Out:
#      Names
# 0   Ramesh
# 1   Suresh
# 2  Sathish
# 3   Mahesh

# %%
pd.DataFrame(Names,'Names')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 pd.DataFrame(Names,'Names')
#
# File E:\Anaconda\Lib\site-packages\pandas\core\frame.py:867, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     859         mgr = arrays_to_mgr(
#     860             arrays,
#     861             columns,
#    (...)
#     864             typ=manager,
#     865         )
#     866     else:
# --> 867         mgr = ndarray_to_mgr(
#     868             data,
#     869             index,
#     870             columns,
#     871             dtype=dtype,
#     872             copy=copy,
#     873             typ=manager,
#     874         )
#     875 else:
#     876     mgr = dict_to_mgr(
#     877         {},
#     878         index,
#    (...)
#     881         typ=manager,
#     882     )
#
# ...

# %%
pd.DataFrame(Names,columns=['Names'])
# Out:
#      Names
# 0   Ramesh
# 1   Suresh
# 2  Sathish
# 3   Mahesh

# %%
#pd.DataFrame(data,index,columns,dtype,copy)
pd.DataFrame(Names)
pd.DataFrame(Names,columns=['Names'])
pd.DataFrame(Names,
             index=['A','B','C','D'],
             columns=['Names'])
# Out:
#      Names
# A   Ramesh
# B   Suresh
# C  Sathish
# D   Mahesh

# %%
Names=['Ramesh','Suresh','Sathish','Mahesh']
Age=[20,22,24,26]
#pd.DataFrame(data,index,columns)
pd.DataFrame(Names,Age)
# Out:
#           0
# 20   Ramesh
# 22   Suresh
# 24  Sathish
# 26   Mahesh

# %%
Names=['Ramesh','Suresh','Sathish','Mahesh']
Age=[20,22,24,26]
DATA=[Names,Age]
#pd.DataFrame(data,index,columns)
pd.DataFrame(DATA).T
# Out:
#          0   1
# 0   Ramesh  20
# 1   Suresh  22
# 2  Sathish  24
# 3   Mahesh  26

# %%
Names=['Ramesh','Suresh','Sathish','Mahesh']
Age=[20,22,24,26]
DATA=zip(Names,Age)
pd.DataFrame(DATA,
             columns=['Names','Age'])
# Out:
#      Names  Age
# 0   Ramesh   20
# 1   Suresh   22
# 2  Sathish   24
# 3   Mahesh   26

# %% [markdown]
# **Step-2: Add a new column to already an existed df**

# %%
Names=['Ramesh','Suresh','Sathish','Mahesh']
Age=[20,22,24,26]
DATA=zip(Names,Age)
df=pd.DataFrame(DATA,columns=['Names','Age'])

# %%
df
# Out:
#      Names  Age
# 0   Ramesh   20
# 1   Suresh   22
# 2  Sathish   24
# 3   Mahesh   26

# %%
#df[col_name] # Selection
           # updation
           # creation

# %%
df['Names']
# Out:
# 0     Ramesh
# 1     Suresh
# 2    Sathish
# 3     Mahesh
# Name: Names, dtype: object

# %%
df['Age']=[30,32,34,36]

# %%
df
# Out:
#      Names  Age
# 0   Ramesh   30
# 1   Suresh   32
# 2  Sathish   34
# 3   Mahesh   36

# %%
df['City']=['Hyd','Pune','Blr','Bihta']
df
# Out:
#      Names  Age   City
# 0   Ramesh   30    Hyd
# 1   Suresh   32   Pune
# 2  Sathish   34    Blr
# 3   Mahesh   36  Bihta

# %% [markdown]
# - created a dataframe with one column
#
# - learned how to add a column names
#
# - learned how to change the index
#
# - created a dataframe with two coulmns uisng zip
#
# - understood how to select update and create new column with already existed dataframe

# %% [markdown]
# **Step-3: How to add data to empty dataframe**

# %%
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#df['Names'] # Im selcting a column : Names
df['Names']=['Ramesh','Suresh','Sathish']
df['Age'] =[20,22,24]
df['City']=['Hyd','Blr','Chennai']
df
# Out:
#      Names  Age     City
# 0   Ramesh   20      Hyd
# 1   Suresh   22      Blr
# 2  Sathish   24  Chennai

# %% [markdown]
# **Step-4: Create a Dataframe using Dictionary**

# %%
d={'Names':['Ramesh','Suresh','Sathish'],
  'Age':[20,22,24],
   'City':['Hyd','Pune','Delhi']}
d
# Out:
# {'Names': ['Ramesh', 'Suresh', 'Sathish'],
#  'Age': [20, 22, 24],
#  'City': ['Hyd', 'Pune', 'Delhi']}

# %%
df=pd.DataFrame(d)
df
# Keys become columns
# Values become rows
# Out:
#      Names  Age   City
# 0   Ramesh   20    Hyd
# 1   Suresh   22   Pune
# 2  Sathish   24  Delhi

# %%
d={'Names':'Ramesh',
  'Age':20,
   'City':'Hyd'}
pd.DataFrame(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 4
#       1 d={'Names':'Ramesh',
#       2   'Age':20,
#       3    'City':'Hyd'}
# ----> 4 pd.DataFrame(d)
#
# File E:\Anaconda\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File E:\Anaconda\Lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %%
#If using all scalar values, you must pass an index
d={'Names':'Ramesh',
  'Age':20,
   'City':'Hyd'}
pd.DataFrame(d,index=[0,1,2])
# Out:
#     Names  Age City
# 0  Ramesh   20  Hyd
# 1  Ramesh   20  Hyd
# 2  Ramesh   20  Hyd

# %% [markdown]
# **Step-5: drop a new column**

# %%
d={'Names':['Ramesh','Suresh','Sathish'],
  'Age':[20,22,24],
   'City':['Hyd','Pune','Delhi']}
df=pd.DataFrame(d)
df
# Out:
#      Names  Age   City
# 0   Ramesh   20    Hyd
# 1   Suresh   22   Pune
# 2  Sathish   24  Delhi

# %%
df.drop(Lables,axis=0,index,columns,inplace=True)  # Index or column
# default behaviour
# Defualt it is conisder index or column
# Doc string shift+tab

# %%
# lables,axis=0
# axis=0 index drop
# axis=1 clumn drop
df.drop('City') # City consider as index
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 4
#       1 # lables,axis=0
#       2 # axis=0 index drop
#       3 # axis=1 clumn drop
# ----> 4 df.drop('City')
#
# File E:\Anaconda\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
df.drop('City',axis=1)
# Out:
#      Names  Age
# 0   Ramesh   20
# 1   Suresh   22
# 2  Sathish   24

# %%
df.drop(lables,axis)
df.drop('City',axis=0) # Index drop error
df.drop('City',axis=1) # Clumn drop

df.drop(columns=['City'])
df.drop(<arguments>)
df.drop(a,b,c,d)
df.drop(2)  # 2 == column  2 == index
df.drop(2,axis=0) # label 2 it is a index
df.drop('City')  # City is a index
df.drop('City',axis=1)
#################################
df.drop(columns=['City'])
df.drop(index=[2])

# %%
df.drop('City')
df.drop('City',axis=1)
df.drop(columns=['City'])
df.drop(2)
df.drop(2,axis=1)
df.drop(2,axis=0)
df.drop(index=[2])

# %%
df.drop('City',axis=1,inplace=True)
# inplace = False
# inplace = True overwrite the output in same df

# %%
df
# Out:
#      Names  Age
# 0   Ramesh   20
# 1   Suresh   22
# 2  Sathish   24

# %%
**Step-6: rename**

- rename the column 

- rename the index

# %%
d={'Names':['Ramesh','Suresh','Sathish'],
  'Age':[20,22,24],
   'City':['Hyd','Pune','Delhi']}
df=pd.DataFrame(d)
df
# Out:
#      Names  Age   City
# 0   Ramesh   20    Hyd
# 1   Suresh   22   Pune
# 2  Sathish   24  Delhi

# %%
#df.rename(mapper)
# mapper means dictionary
c={'City':'Citi'}
df.rename(c, axis=1)  # 1 level

df.rename(columns=c)  # 2 level
# Out:
#      Names  Age   Citi
# 0   Ramesh   20    Hyd
# 1   Suresh   22   Pune
# 2  Sathish   24  Delhi

# %% [markdown]
# **Step-7: Save the datarame**

# %% [markdown]
# - .csv
#
# - .xlsx
#
# - where you want to save: directory
#
# - on what name you want save: name of the file
#
# - on what extension you can use: .csv,.xlsx
#
# - differnt location : "C:\Users\omkar\OneDrive\Documents\Gen_AI\df1.csv"
#
# - "C:\Users\omkar\OneDrive\Documents\Gen_AI\df1.xlsx"
#
# - same location: no need to provide directory: 'df1.csv'

# %%
df.to_csv(r"C:\Users\omkar\OneDrive\Documents\Gen_AI\df1.csv",index=False)
df.to_csv('df1.csv',index=False)

# %%
df.to_csv(r"C:\Users\omkar\OneDrive\Documents\Gen_AI\df2.csv")

# %% [markdown]
# **Step-8:How to read a Dataframe**

# %%
pd.read_csv(r"C:\Users\omkar\OneDrive\Documents\Gen_AI\df1.csv")
pd.read_csv('df1.csv')
# Out:
#      Names  Age   City
# 0   Ramesh   20    Hyd
# 1   Suresh   22   Pune
# 2  Sathish   24  Delhi

# %%
pd.read_excel(<full path>)
