# %% [markdown]
# **Step-1: Read the packages**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Step-2: Read the datasets**

# %%
visa_df=pd.read_csv(r"C:\Users\Admin\OneDrive\Documents\EDA\Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
bank_df=pd.read_csv(r"C:\Users\Admin\OneDrive\Documents\EDA\bank.csv",sep=';')
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# **Step-3:Data Qucik Checks**

# %% [markdown]
# **us visa_df**
#
# - visa_df.shape
#
# - visa_df.size
#
# - head
#
# - tail
#
# - dtypes
#
# - columns
#
# - isnull
#
# - info

# %%
visa_df.shape
print(f'The number of rows are:{visa_df.shape[0]}')
print(f'The number of columns are:{visa_df.shape[1]}')
# Out:
# The number of rows are:25480
# The number of columns are:12

# %%
type(visa_df)
# Out:
# pandas.core.frame.DataFrame

# %%
visa_df.size
# Number of entries
# Out:
# 305760

# %%
cols=visa_df.columns
cols
# What are the columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
# what is the index of 'yr_of_estab'
cols.index('yr_of_estab')
# Out:
# ------------------------------------------------------------------------
# AttributeError                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 # what is the index of 'yr_of_estab'
# ----> 2 cols.index('yr_of_estab')
#
# AttributeError: 'Index' object has no attribute 'index'

# %%
cols=visa_df.columns.tolist()
cols.index('yr_of_estab')
# Out:
# 6

# %%
visa_df.head(3)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied

# %%
visa_df.tail(3)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25477                South        146298.85         Year                  N
# 25478                 West         86154.77         Year                  Y
# 25479              Midwest         70876.91         Year                  Y
#
#       case_status
# 25477   Certified
# 25478   Certified
# 25479   Certified

# %%
# How you are seeing a df in the numpy language
# pandas ==== Numpy
# I df 25480 rows 12 columns  25480x12
# Numpy : Bro i have a array having 12 values: 12 columns
#        these list are repeating 25480 time 

np.array([[1,2,3,4]]).shape  # I have a list of 4 value 1 time
np.array([[1,2,3,4],[10,20,30,40]]).shape # I have a list of 4 values 2 times 
#  4 columns 2 rows
# Out:
# (2, 4)

# %%
#[[1,2,3.....12],[],[].......25480]
visa_df # pandas
visa_df.values # numpy arrays
# Out:
# array([['EZYV01', 'Asia', 'High School', ..., 'Hour', 'Y', 'Denied'],
#        ['EZYV02', 'Asia', "Master's", ..., 'Year', 'Y', 'Certified'],
#        ['EZYV03', 'Asia', "Bachelor's", ..., 'Year', 'Y', 'Denied'],
#        ...,
#        ['EZYV25478', 'Asia', "Master's", ..., 'Year', 'N', 'Certified'],
#        ['EZYV25479', 'Asia', "Master's", ..., 'Year', 'Y', 'Certified'],
#        ['EZYV25480', 'Asia', "Bachelor's", ..., 'Year', 'Y', 'Certified']],
#       shape=(25480, 12), dtype=object)

# %% [markdown]
# **loc-iloc**

# %%
#visa_df.iloc[rows,columns]
#visa_df.iloc[start:stop:step,start:stop:step]
visa_df.iloc[2:6,3:7]
# rows: 2:6  2,3,4,5
# columns: 3:7, 3,4,5,6
# Out:
#   has_job_experience requires_job_training  no_of_employees  yr_of_estab
# 2                  N                     Y            44444         2008
# 3                  N                     N               98         1897
# 4                  Y                     N             1082         2005
# 5                  Y                     N             2339         2012

# %%
# loc will use ful we can provide direct column names
# no need of indexes
cols=['has_job_experience','requires_job_training']
visa_df.loc[2:6,cols]
# Out:
#   has_job_experience requires_job_training
# 2                  N                     Y
# 3                  N                     N
# 4                  Y                     N
# 5                  Y                     N
# 6                  N                     N

# %%
visa_df.iloc[2:6,3:7]
cols=['has_job_experience','requires_job_training']
visa_df.loc[2:6,cols]

# %%
visa_df.iloc[[100,200,300]]
visa_df.iloc[[100,200,300],:3]
visa_df.iloc[[100,200,300],[3,9]]
# Out:
#     has_job_experience unit_of_wage
# 100                  Y         Year
# 200                  Y         Year
# 300                  Y         Year

# %%
# Every student should undersnd
# 1D and 2D 
# list []   Numpy : 1D   Pandas === series
# list [[]] Numpy : 2D   Pandas === dataframe

# %%
visa_df  # df: column names

visa_df['continent'] # series  no column name
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df.values
# Out:
# array([['EZYV01', 'Asia', 'High School', ..., 'Hour', 'Y', 'Denied'],
#        ['EZYV02', 'Asia', "Master's", ..., 'Year', 'Y', 'Certified'],
#        ['EZYV03', 'Asia', "Bachelor's", ..., 'Year', 'Y', 'Denied'],
#        ...,
#        ['EZYV25478', 'Asia', "Master's", ..., 'Year', 'N', 'Certified'],
#        ['EZYV25479', 'Asia', "Master's", ..., 'Year', 'Y', 'Certified'],
#        ['EZYV25480', 'Asia', "Bachelor's", ..., 'Year', 'Y', 'Certified']],
#       shape=(25480, 12), dtype=object)

# %%
visa_df['continent'].values
# Out:
# array(['Asia', 'Asia', 'Asia', ..., 'Asia', 'Asia', 'Asia'],
#       shape=(25480,), dtype=object)

# %%
visa_df
visa_df['continent'] # 1D S
visa_df[['continent']] # 2D df
rows=[100,200,300]
visa_df.iloc[rows,3] # 1d S
visa_df.iloc[rows,[3]] # 2D D
visa_df.loc[rows,'continent'] # 1 D
visa_df.loc[rows,['continent']] # 2D
# Out:
#     continent
# 100      Asia
# 200      Asia
# 300      Asia

# %%
visa_df # df  2d
visa_df.values # arrays  2d 
# there are 12 columns
# a list has 12 values 
# list is repeating 25480 rows
# Out:
# array([['EZYV01', 'Asia', 'High School', ..., 'Hour', 'Y', 'Denied'],
#        ['EZYV02', 'Asia', "Master's", ..., 'Year', 'Y', 'Certified'],
#        ['EZYV03', 'Asia', "Bachelor's", ..., 'Year', 'Y', 'Denied'],
#        ...,
#        ['EZYV25478', 'Asia', "Master's", ..., 'Year', 'N', 'Certified'],
#        ['EZYV25479', 'Asia', "Master's", ..., 'Year', 'Y', 'Certified'],
#        ['EZYV25480', 'Asia', "Bachelor's", ..., 'Year', 'Y', 'Certified']],
#       shape=(25480, 12), dtype=object)

# %%
visa_df['continent']
visa_df['continent'].values # raw data
# Out:
# array(['Asia', 'Asia', 'Asia', ..., 'Asia', 'Asia', 'Asia'],
#       shape=(25480,), dtype=object)

# %%
visa_df[['continent','case_status']]
visa_df[['continent','case_status']].values
# Out:
# array([['Asia', 'Denied'],
#        ['Asia', 'Certified'],
#        ['Asia', 'Denied'],
#        ...,
#        ['Asia', 'Certified'],
#        ['Asia', 'Certified'],
#        ['Asia', 'Certified']], shape=(25480, 2), dtype=object)

# %%
# 1D is only one list : Raw data of a specific column
visa_df['continent'].values # [25480]

# 2d is a list has 2 values : DF 2 column
# Out:
# array(['Asia', 'Asia', 'Asia', ..., 'Asia', 'Asia', 'Asia'],
#       shape=(25480,), dtype=object)

# %%
visa_df['continent'] # S
visa_df[['continnet']] # D
visa_df.iloc[[100,200,300],3] # S
visa_df.iloc[[100,200,300],[3]] # D
visa_df.loc[[100,200,300],'continnet'] # S
visa_df.loc[[100,200,300],['continnet']] # D
# Out:
# ------------------------------------------------------------------------
# KeyError                               Traceback (most recent call last)
# Cell In[31], line 2
#       1 visa_df['continent'] # S
# ----> 2 visa_df[['continnet']] # D
#       3 visa_df.iloc[[100,200,300],3] # S
#       4 visa_df.iloc[[100,200,300],[3]] # D
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
# ...

# %% [markdown]
# **dtypes**
#
# - every series is a key value pair
#
# - every series is dictionary
#
# - in dictionary if we want keys: .keys()
#
# - in dictionary if we want values: .values

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %% [markdown]
# **task-1**

# %%
keys=visa_df.dtypes.keys().tolist()
values=visa_df.dtypes.values.tolist()
pd.DataFrame(zip(keys,values),columns=['Name','Data type'])
# Out:
#                      Name Data type
# 0                 case_id    object
# 1               continent    object
# 2   education_of_employee    object
# 3      has_job_experience    object
# 4   requires_job_training    object
# 5         no_of_employees     int64
# 6             yr_of_estab     int64
# 7    region_of_employment    object
# 8         prevailing_wage   float64
# 9            unit_of_wage    object
# 10     full_time_position    object
# 11            case_status    object

# %%
visa_df.dtypes.values
# Out:
# array([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('int64'), dtype('int64'), dtype('O'), dtype('float64'),
#        dtype('O'), dtype('O'), dtype('O')], dtype=object)

# %%
df=pd.DataFrame(visa_df.dtypes).reset_index()
df.columns=['Name','Data type']
df
# Out:
#                      Name Data type
# 0                 case_id    object
# 1               continent    object
# 2   education_of_employee    object
# 3      has_job_experience    object
# 4   requires_job_training    object
# 5         no_of_employees     int64
# 6             yr_of_estab     int64
# 7    region_of_employment    object
# 8         prevailing_wage   float64
# 9            unit_of_wage    object
# 10     full_time_position    object
# 11            case_status    object

# %% [markdown]
# **task-2**

# %%
visa_df.dtypes
# idea 
# extract keys and values
# apply the for loop on values
# for i,j in zip(values,keys):
#  if i =='object':
#      j  

keys=visa_df.dtypes.keys().tolist()
values=visa_df.dtypes.values.tolist()
cat,num=[],[]
for i,j in zip(keys,values):
    if j=='object':
        cat.append(i)
    else:
        num.append(j)
cat,num
# Out:
# (['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  [dtype('int64'), dtype('int64'), dtype('float64')])

# %% [markdown]
# **select_dtypes**

# %%
visa_df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.select_dtypes(exclude='object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')
